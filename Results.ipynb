# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data= pd.read_csv("../RR1.csv")
data['SMA30'] = data['score'].rolling(1000).mean()
data1 = pd.read_csv("../FF.csv")
data['A30'] = data1['score'].rolling(1000).mean()
print(data['SMA30'][344500:])
f = plt.figure()
f.set_figwidth(40)
f.set_figheight(20)
plt.plot(data['SMA30'], color='r', label='RR1')
plt.plot(data['A30'], color='b', label='RR')
plt.grid()
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.yticks(np.arange(-10, 11, 1))
plt.show()
# Out:
# Series([], Name: SMA30, dtype: float64)

# %%
data= pd.read_csv("../FF.csv")
j = 0
k = 0
for i in data['score']:
    k+=1
    if i >= 10 :
        j +=1
print(j*100/k)
# Out:
# 12.420842128652373
